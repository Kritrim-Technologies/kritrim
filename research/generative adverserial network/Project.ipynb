65714286]), array([0.63809524]), array([0.56190476]), array([0.65714286]), array([0.57142857]), array([0.63809524]), array([0.57142857]), array([0.57142857]), array([0.60952381]), array([0.63809524]), array([0.60952381]), array([0.56190476]), array([0.54285714]), array([0.61904762]), array([0.63809524]), array([0.61904762]), array([0.57142857]), array([0.60952381]), array([0.57142857]), array([0.60952381]), array([0.61904762]), array([0.60952381]), array([0.61904762]), array([0.52380952]), array([0.54285714]), array([0.60952381]), array([0.56190476]), array([0.56190476]), array([0.57142857]), array([0.57142857]), array([0.60952381]), array([0.59047619]), array([0.60952381]), array([0.5047619]), array([0.52380952]), array([0.59047619]), array([0.54285714]), array([0.54285714]), array([0.57142857]), array([0.59047619]), array([0.57142857]), array([0.59047619]), array([0.63809524]), array([0.5047619]), array([0.4952381]), array([0.63809524]), array([0.56190476]), array([0.56190476]), array([0.60952381]), array([0.63809524]), array([0.60952381]), array([0.65714286]), array([0.63809524]), array([0.54285714]), array([0.4952381]), array([0.57142857]), array([0.65714286]), array([0.60952381]), array([0.57142857]), array([0.65714286]), array([0.60952381]), array([0.65714286]), array([0.54285714]), array([0.52380952]), array([0.60952381]), array([0.60952381]), array([0.54285714]), array([0.57142857]), array([0.54285714]), array([0.57142857]) ...

# %%
notes = [list(note) for note in notes]

# subsample data for training and prediction
X = []
y = []
# number of notes in a batch
n_prev = 100
for i in range(len(notes)-n_prev):
    X.append(notes[i:i+n_prev])
X = np.array(X)
print(X.shape)
X[0, :, :]
# Out:
# (12004, 100, 1)
# array([[0.34285714],
#        [0.45714286],
#        [0.52380952],
#        [0.57142857],
#        [0.52380952],
#        [0.57142857],
#        [0.59047619],
#        [0.59047619],
#        [0.60952381],
#        [0.60952381],
#        [0.52380952],
#        [0.57142857],
#        [0.52380952],
#        [0.57142857],
#        [0.60952381],
#        [0.60952381],
#        [0.59047619],
#        [0.59047619],
#        [0.5047619 ],
#        [0.5047619 ],
#        [0.57142857],
#        [0.57142857],
#        [0.59047619],
#        [0.59047619],
#        [0.61904762],
#        [0.61904762],
#        [0.54285714],
#        [0.56190476],
#        [0.54285714],
#        [0.56190476],
#        [0.61904762],
#        [0.61904762],
#        [0.60952381],
#        [0.60952381],
#        [0.52380952],
#        [0.52380952],
#        [0.57142857],
#        [0.60952381],
#        [0.57142857],
#        [0.63809524],
#        [0.60952381],
#        [0.56190476],
#        [0.63809524],
#        [0.56190476],
#        [0.57142857],
#        [0.57142857],
#        [0.63809524],
#        [0.61904762],
#        [0.63809524],
#        [0.61904762],
#        [0.54285714],
#        [0.54285714],
#        [0.57142857],
#        [0.61904762],
#        [0.57142857],
#        [0.61904762],
#        [0.65714286],
#        [0.56190476],
#        [0.65714286],
#        [0.61904762],
#        [0.56190476],
#        [0.61904762],
#        [0.65714286],
#        [0.65714286],
#        [0.63809524],
#        [0.63809524],
#        [0.34285714],
#        [0.57142857],
#        [0.45714286],
#        [0.57142857],
#        [0.60952381],
#        [0.63809524],
#        [0.60952381],
#        [0.68571429],
#        [0.63809524],
#        [0.57142857],
#        [0.68571429],
#        [0.60952381],
#        [0.60952381],
#        [0.63809524],
#        [0.63809524],
#        [0.68571429],
#        [0.68571429],
#        [0.56190476],
#        [0.7047619 ],
#        [0.7047619 ],
#        [0.60952381],
#        [0.60952381],
#        [0.63809524],
#        [0.63809524],
#        [0.7047619 ],
#        [0.68571429],
#        [0.7047619 ],
#        [0.54285714],
#        [0.56190476],
#        [0.68571429],
#        [0.60952381],
#        [0.63809524],
#        [0.60952381],
#        [0.63809524]])

# %%
def generator():
    gen_input = Input(shape = (None, 100))
    X = LSTM(256, return_sequences = True)(gen_input)
    X = Dropout(0.5)(X)
    X = LSTM(128, return_sequences = True)(X)
    X = Dropout(0.5)(X)
    X = LSTM(64, return_sequences = True)(X)
    X = Dropout(0.5)(X)
    out = Dense(1, activation = "relu")(X)
    model = Model(inputs = gen_input, outputs = out)
    return model

# %%
def discriminator():
    disc_input = Input(shape = (100, 1))
    X = LSTM(128, return_sequences = True)(disc_input)
    X = Dropout(0.3)(X)
    X = LSTM(64, return_sequences = True)(X)
    X = Dropout(0.3)(X)
    X = Flatten()(X)
    X = Dense(128, activation = "relu")(X)
    X = Dropout(0.3)(X)
    out = Dense(1, activation = "sigmoid")(X)
    model = Model(inputs = disc_input, outputs = out)
    return model

# %%
def disc_with_gen(generator, discriminator):
    inputs = Input(shape = (None, 100))
    generated = generator(inputs)
    outputs = discriminator(generated)
    model = Model(inputs = inputs, outputs = outputs)
    return model

# %%
from tensorflow.keras.optimizers import Adam
optimizer = Adam(0.0002, 0.5)
d = discriminator()
d.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
g = generator()

# %%
d.trainable = False
combined = disc_with_gen(g, d)
combined.compile(loss='binary_crossentropy', optimizer=optimizer)

# %%
X.shape
# Out:
# (12004, 100, 1)

# %%
from matplotlib import pyplot as plt
assert not np.any(np.isnan(X))
#generated = g.predict(noise)
#generated

# %%
disc_loss = []
gen_loss = []

# %%
idx = list(range(0, 64, 1))
real_data = X[idx]
real_data.shape
# Out:
# (64, 100, 1)

# %%
def train(epochs, num_of_batches, batch_size = 64):
    for epoch in range(epochs):
        a = 0
        b = 64
        for num in range(num_of_batches):
            idx = list(range(a, b, 1))
            real_data = X[idx]

            noise = np.random.normal(0, 1, (64, 100, 100))

            generated = g.predict(noise)
            d_loss_real = d.train_on_batch(real_data, np.ones((64, 1)))
            d_loss_fake = d.train_on_batch(generated, np.zeros((64, 1)))
            d_loss = 0.5 * np.add(real_loss, fake_loss)
            
            noise = np.random.normal(0, 1, (64, 100, 100))
            g_loss = combined.train_on_batch(noise, np.ones((64, 1)))

            a = a + 64
            b = b + 64
            
        if epoch % 1 == 0:
            print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_loss[0], 100*d_loss[1], g_loss))
            disc_loss.append(d_loss[0])
            gen_loss.append(g_loss)
            
    plt.plot(disc_loss, c='red')
    plt.plot(gen_loss, c='blue')
    plt.title("GAN Loss per Epoch")
    plt.legend(['Discriminator', 'Generator'])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.savefig('GAN_Loss_per_Epoch_final.png', transparent=True)
    plt.close()

# %%
train(epochs = 5, num_of_batches = 187)
# Out:
# 0 [D loss: 0.694071, acc.: 50.00%] [G loss: 0.699262]
# 1 [D loss: 0.693166, acc.: 50.00%] [G loss: 0.694989]
# 2 [D loss: 0.693216, acc.: 49.22%] [G loss: 0.696492]
# 3 [D loss: 0.693169, acc.: 50.00%] [G loss: 0.696275]
# 4 [D loss: 0.693169, acc.: 50.00%] [G loss: 0.696294]

# %%
pred = g.predict(np.random.normal(0, 1, (1, 100, 100)))
d.predict(pred)
# Out:
# array([[0.49842876]], dtype=float32)

# %%
d.predict(X[100, :, :].reshape(1, 100, 1))
# Out:
# array([[0.49842876]], dtype=float32)

# %%
prediction = g.predict(np.random.normal(0, 1, (1, 100, 100)))
prediction = np.squeeze(prediction)
prediction = np.squeeze(scaler.inverse_transform(prediction.reshape(-1,1)))
prediction = [int(i) for i in prediction]
#prediction = np.argmax(prediction, -1)

# %%
print(prediction)
#prediction = np.squeeze(prediction)
# Out:
# [56, 101, 84, 55, 58, 107, 120, 71, 40, 45, 87, 121, 99, 55, 34, 54, 90, 83, 52, 33, 58, 84, 79, 48, 32, 71, 113, 106, 75, 72, 67, 73, 94, 93, 79, 55, 63, 104, 120, 88, 53, 54, 93, 118, 88, 48, 36, 50, 67, 64, 49, 44, 42, 41, 41, 46, 68, 90, 78, 57, 53, 64, 78, 74, 53, 36, 38, 51, 61, 69, 69, 82, 90, 89, 82, 85, 76, 78, 89, 98, 93, 79, 66, 69, 78, 93, 95, 96, 81, 69, 75, 95, 92, 64, 58, 78, 92, 80, 63, 61]

# %%
from mido import MidiFile, MidiTrack, Message
mid = MidiFile()
track = MidiTrack()
t = 230
for note in prediction:
    # 147 means note_on
    # 67 is velocity
    note = np.asarray([147, note, 67])
    bytes = note.astype(int)
    msg = Message.from_bytes(bytes[0:3])
    if t >= 160:
        t -= 2
    msg.time = int(t)
    track.append(msg)
mid.tracks.append(track)
mid.save('LSTM_music.mid')

# %%
g.save("Model1.h5")

# %%
g.save_weights("Model1_weights.h5")

# %%
loaded = tf.keras.models.load_model("Model1.h5")

# %%
import mido
from mido import MidiFile, MidiTrack, Message
import numpy as np

mid = MidiFile('LSTM_music.mid')
#mid = MidiFile('pnowks/corner.mid') 
notes = []

for msg in mid:
    print(msg)
# Out:
# note_on channel=3 note=56 velocity=67 time=0.2375
# note_on channel=3 note=101 velocity=67 time=0.23541666666666666
# note_on channel=3 note=84 velocity=67 time=0.23333333333333334
# note_on channel=3 note=55 velocity=67 time=0.23124999999999998
# note_on channel=3 note=58 velocity=67 time=0.22916666666666666
# note_on channel=3 note=107 velocity=67 time=0.22708333333333333
# note_on channel=3 note=120 velocity=67 time=0.225
# note_on channel=3 note=71 velocity=67 time=0.22291666666666665
# note_on channel=3 note=40 velocity=67 time=0.22083333333333333
# note_on channel=3 note=45 velocity=67 time=0.21875
# note_on channel=3 note=87 velocity=67 time=0.21666666666666667
# note_on channel=3 note=121 velocity=67 time=0.21458333333333332
# note_on channel=3 note=99 velocity=67 time=0.2125
# note_on channel=3 note=55 velocity=67 time=0.21041666666666667
# note_on channel=3 note=34 velocity=67 time=0.20833333333333334
# note_on channel=3 note=54 velocity=67 time=0.20625
# note_on channel=3 note=90 velocity=67 time=0.20416666666666666
# note_on channel=3 note=83 velocity=67 time=0.20208333333333334
# note_on channel=3 note=52 velocity=67 time=0.2
# note_on channel=3 note=33 velocity=67 time=0.19791666666666666
# note_on channel=3 note=58 velocity=67 time=0.19583333333333333
# note_on channel=3 note=84 velocity=67 time=0.19375
# note_on channel=3 note=79 velocity=67 time=0.19166666666666665
# note_on channel=3 note=48 velocity=67 time=0.18958333333333333
# note_on channel=3 note=32 velocity=67 time=0.1875
# note_on channel=3 note=71 velocity=67 time=0.18541666666666667
# note_on channel=3 note=113 velocity=67 time=0.18333333333333332
# note_on channel=3 note=106 velocity=67 time=0.18125
# note_on channel=3 note=75 velocity=67 time=0.17916666666666667
# note_on channel=3 note=72 velocity=67 time=0.17708333333333334
# note_on channel=3 note=67 velocity=67 time=0.175
# note_on channel=3 note=73 velocity=67 time=0.17291666666666666
# note_on channel=3 note=94 velocity=67 time=0.17083333333333334
# note_on channel=3 note=93 velocity=67 time=0.16875
# note_on channel=3 note=79 velocity=67 time=0.16666666666666666
# note_on channel=3 note=55 velocity=67 time=0.16458333333333333
# note_on channel=3 note=63 velocity=67 time=0.16458333333333333
# note_on channel=3 note=104 velocity=67 time=0.16458333333333333
# note_on channel=3 note=120 velocity=67 time=0.16458333333333333
# note_on channel=3 note=88 velocity=67 time=0.16458333333333333
# note_on channel=3 note=53 velocity=67 time=0.16458333333333333
# note_on channel=3 note=54 velocity=67 time=0.16458333333333333
# note_on channel=3 note=93 velocity=67 time=0.16458333333333333
# note_on channel=3 note=118 velocity=67 time=0.16458333333333333
# note_on channel=3 note=88 velocity=67 time=0.16458333333333333
# note_on channel=3 note=48 velocity=67 time=0.16458333333333333
# note_on channel=3 note=36 velocity=67 time=0.16458333333333333
# note_on channel=3 note=50 velocity=67 time=0.16458333333333333
# note_on channel=3 note=67 velocity=67 time=0.16458333333333333
# note_on channel=3 note=64 velocity=67 time=0.16458333333333333
# note_on channel=3 note=49 velocity=67 time=0.16458333333333333
# note_on channel=3 note=44 velocity=67 time=0.16458333333333333
# note_on channel=3 note=42 velocity=67 time=0.16458333333333333
# note_on channel=3 note=41 velocity=67 time=0.16458333333333333
# note_on channel=3 note=41 velocity=67 time=0.16458333333333333
# note_on channel=3 note=46 velocity=67 time=0.16458333333333333
# note_on channel=3 note=68 velocity=67 time=0.16458333333333333
# note_on channel=3 note=90 velocity=67 time=0.16458333333333333
# note_on channel=3 note=78 velocity=67 time=0.16458333333333333
# note_on channel=3 note=57 velocity=67 time=0.16458333333333333
# note_on channel=3 note=53 velocity=67 time=0.16458333333333333
# note_on channel=3 note=64 velocity=67 time=0.16458333333333333
# note_on channel=3 note=78 velocity=67 time=0.16458333333333333
# note_on channel=3 note=74 velocity=67 time=0.16458333333333333
# note_on channel=3 note=53 velocity=67 time=0.16458333333333333
# note_on channel=3 note=36 velocity=67 time=0.16458333333333333
# note_on channel=3 note=38 velocity=67 time=0.16458333333333333
# note_on channel=3 note=51 velocity=67 time=0.16458333333333333
# note_on channel=3 note=61 velocity=67 time=0.16458333333333333
# note_on channel=3 note=69 velocity=67 time=0.16458333333333333
# note_on channel=3 note=69 velocity=67 time=0.16458333333333333
# note_on channel=3 note=82 velocity=67 time=0.16458333333333333
# note_on channel=3 note=90 velocity=67 time=0.16458333333333333
# note_on channel=3 note=89 velocity=67 time=0.16458333333333333
# note_on channel=3 note=82 velocity=67 time=0.16458333333333333
# note_on channel=3 note=85 velocity=67 time=0.16458333333333333
# note_on channel=3 note=76 velocity=67 time=0.16458333333333333
# note_on channel=3 note=78 velocity=67 time=0.16458333333333333
# note_on channel=3 note=89 velocity=67 time=0.16458333333333333
# note_on channel=3 note=98 velocity=67 time=0.16458333333333333
# note_on channel=3 note=93 velocity=67 time=0.16458333333333333
# note_on channel=3 note=79 velocity=67 time=0.16458333333333333
# note_on channel=3 note=66 velocity=67 time=0.16458333333333333
# note_on channel=3 note=69 velocity=67 time=0.16458333333333333
# note_on channel=3 note=78 velocity=67 time=0.16458333333333333
# note_on channel=3 note=93 velocity=67 time=0.16458333333333333
# note_on channel=3 note=95 velocity=67 time=0.16458333333333333
# note_on channel=3 note=96 velocity=67 time=0.16458333333333333
# note_on channel=3 note=81 velocity=67 time=0.16458333333333333
# note_on channel=3 note=69 velocity=67 time=0.16458333333333333
# note_on channel=3 note=75 velocity=67 time=0.16458333333333333
# note_on channel=3 note=95 velocity=67 time=0.16458333333333333
# note_on channel=3 note=92 velocity=67 time=0.16458333333333333
# note_on channel=3 note=64 velocity=67 time=0.16458333333333333
# note_on channel=3 note=58 velocity=67 time=0.16458333333333333
# note_on channel=3 note=78 velocity=67 time=0.16458333333333333
# note_on channel=3 note=92 velocity=67 time=0.16458333333333333
# note_on channel=3 note=80 velocity=67 time=0.16458333333333333
# note_on channel=3 note=63 velocity=67 time=0.16458333333333333
# note_on channel=3 note=61 velocity=67 time=0.16458333333333333
# <meta message end_of_track time=0>

# %%
b = [1,2,3,4,5,6,7,8,9]
a = list(np.array(b).reshape(-1,1))
note = [list(v) for v in a]
print(a)
# Out:
# [array([1]), array([2]), array([3]), array([4]), array([5]), array([6]), array([7]), array([8]), array([9])]
